# %%
import cv2
import matplotlib.pyplot as plt

# %%
file_path = 'test/test_image/0111.jpg'
img = cv2.imread(file_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.title("Horse")
plt.imshow(img)
print(img.shape)
# Out:
# (227, 227, 3)
